# %% [markdown]
# <a href="https://colab.research.google.com/github/triyono303/tugasR.web/blob/main/praktikum7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("./Downloads/USA_Housing.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-458256eb9a29> in <cell line: 1>()
# ----> 1 df = pd.read_csv("./Downloads/USA_Housing.csv")
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
datasetiket.tail(10)
# Out:
#           nama_usaha                                       alamat_usaha  \
# 3947   Xiang Man Lou                Jl. Pluit Kencana Dalam P/28 K.28 L
# 3948       Xo - Suki  Emporium Pluit Mall, Jl. Pluit Selatan Raya, P...
# 3949    Ya Rae Hyang                            Jl. Raya Gading Batavia
# 3950    Ya Rae Hyang               Ruko Gading Batavia Blok LC-9 No. 12
# 3951          Yakoya       Jl. Raya Boulevard Barat Blok LC 6 No. 16-18
# 3952          Yakoya       Jl. Raya Boulevard Barat Blok LC 6 No. 16-18
# 3953  Yamagoya Ramen  Mall Of Indonesia, Jl. Boulevard Barat Raya No. 1
# 3954       Yoshinoya                   Jl. Raya Boulevard Blok XC No. 7
# 3955          Yuraku                 Mal Kelapa Gading I Lt. Dasar #195
# 3956   Yuraku Buffet  Komp. Inkopol Blok C /23 AB, Jl. Boulevard Bar...
#
#                   badan_usaha           penanggung_jawab        wilayah  \
# 3947            XIANG MAN LOU           Tju Liong / Naga  Jakarta Utara
# ...

# %%
import matplotlib.pyplot as plt
gmv_per_order = datasetiket.groupby('order_id')['gross_revenue'].sum().reset_index()
gmv_per_order.head()
plt.figure(figsize=(15,5))
plt.plot(gmv_per_order)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-56a689cf3e50> in <cell line: 2>()
#       1 import matplotlib.pyplot as plt
# ----> 2 gmv_per_order = datasetiket.groupby('order_id')['gross_revenue'].sum().reset_index()
#       3 gmv_per_order.head()
#       4 plt.figure(figsize=(15,5))
#       5 plt.plot(gmv_per_order)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8250         axis = self._get_axis_number(axis)
#    8251
# -> 8252         return DataFrameGroupBy(
#    8253             obj=self,
#    8254             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     929
# ...

# %% [markdown]
# # Bagian Baru
